# %% [markdown]
# <a href="https://colab.research.google.com/github/nishanth-sudo/ML-Laboratory/blob/main/Multivariate_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("dataset/50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.histplot(df['Profit'],bins=30,kde=True, stat="density")
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
numerical_df = df.select_dtypes(include=['number'])

# %%
corr = numerical_df.corr().round(1)

# %%
sns.heatmap(data=corr,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,5))
features=['R&D Spend','Profit']
target=df['Profit']
for i, col in enumerate(features):
    plt.subplot(1, len(features), i + 1)
    x = df[col]
    y = target
    plt.scatter(x, y, marker="o")
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel("Profit")
